# %%
import random
import cudf as pd
import cupy as np

df10_standardized = pd.read_csv("cudf_tru20_al.csv", sep='\t')

def calculate_factor_values(df, factor_expression):
    return df.eval(factor_expression)

def fget_average_pAT10(df, factor_expression):
    df['factor_value'] = calculate_factor_values(df, factor_expression)
    top10_per_user = df.sort_values(['userID', 'factor_value'], ascending=[True, False]).groupby('userID').head(10)
    relevant_count = top10_per_user.groupby('userID')['isFriend'].sum()
    pAT10 = relevant_count / 10.0
    avg_pAT10 = pAT10.mean()
    del df['factor_value']
    del top10_per_user
    return avg_pAT10

def nnget_average_pAT10(df, factor_expression):
    df['factor_value'] = df.eval(factor_expression)
    isFriend_zero_df = df[df['isFriend'] == 0]
    top10_per_user = isFriend_zero_df.sort_values(['userID', 'factor_value'], ascending=[True, False]).groupby('userID').head(10)
    # 计算pAT5
    pAT5 = (top10_per_user.groupby('userID').head(5)['change'] == 1).groupby(top10_per_user['userID']).sum() / 5
    all_users_pAT5 = pAT5.reindex(df['userID'].unique(), fill_value=0)
    avg_pAT5 = all_users_pAT5.mean()
    # 计算pAT10
    pAT10 = (top10_per_user['change'] == 1).groupby(top10_per_user['userID']).sum() / 10
    all_users_pAT10 = pAT10.reindex(df['userID'].unique(), fill_value=0)
    avg_pAT10 = all_users_pAT10.mean()

    avg_pAT = (0.7 * avg_pAT5 + 0.3 * avg_pAT10) * 0.95
    del df['factor_value']
    return avg_pAT

def generate_initial_population(size, columns):
    population = []
    operators = ['+', '-', '*', '/','%','//','**']
    for _ in range(size):
        const_factor = round(random.uniform(0, 1), 6)
        expr = f"{const_factor} * {random.choice(columns)}"
        for _ in range(random.randint(1, 7)):  # Generate expressions with depth between 1 and 5
            const_factor = round(random.uniform(0, 1), 6)
            expr += f" {random.choice(operators)} {const_factor} * {random.choice(columns)}"
        population.append(expr)
    return population


def select(population, fitnesses, num_parents):
    parents = sorted(zip(population, fitnesses), key=lambda x: x[1], reverse=True)[:num_parents]
    return [expr for expr, _ in parents]

def crossover(parent1, parent2):
    parts1 = parent1.split(' ')
    parts2 = parent2.split(' ')
    if len(parts1) > 1 and len(parts2) > 1:
        crossover_point = random.randint(1, min(len(parts1), len(parts2)) - 1)
        child = ' '.join(parts1[:crossover_point] + parts2[crossover_point:])
        return child
    return parent1

def mutate(expression, columns, mutation_rate=0.1):
    parts = expression.split(' ')
    if random.random() < mutation_rate:
        index = random.randint(0, len(parts) - 1)
        if index % 2 == 0:
            const_factor = round(random.uniform(0, 1), 4)
            parts[index] = f"{const_factor} * {random.choice(columns)}"
        else:
            parts[index] = random.choice(['+', '-', '*', '/','%','//','**'])
    return ' '.join(parts)


def genetic_algorithm(df, columns, population_size, num_generations, num_parents, mutation_rate):
    population = generate_initial_population(population_size, columns)

    for generation in range(num_generations):
        #fitnesses = [nget_average_pAT10(df, expr) for expr in population]
        #fitnesses = [fget_average_pAT10(df, expr) for expr in population]
        fitnesses = [nnget_average_pAT10(df, expr) for expr in population]
        max_index = fitnesses.index(max(fitnesses))
        best_expr = population[max_index]
        best_fitness = fitnesses[max_index]
        
        print(f'Generation {generation + 1}: Best fitness {best_fitness}, Best expression {best_expr}')

        parents = select(population, fitnesses, num_parents)
        next_population = parents[:2]  # Keep the best individuals

        while len(next_population) < population_size:
            parent1, parent2 = random.sample(parents, 2)
            child = crossover(parent1, parent2)
            child = mutate(child, columns, mutation_rate)
            next_population.append(child)

        population = next_population

    best_expr = select(population, [nnget_average_pAT10(df, expr) for expr in population], 1)[0]
    return best_expr

columns = ['nFriends_x', 'nFriends_y', 'cn', 'per_fName_y', 'per_gender_y', 'per_homeCity_y', 'per_location_y', 'per_privacy_y', 'per_homeProvince_y']
best_expression = genetic_algorithm(df10_standardized, columns, population_size=15000, num_generations=400, num_parents=1500, mutation_rate=0.65)
print('Best Expression:', best_expression)
# Out:
# Generation 1: Best fitness 0.7879999999999999, Best expression 0.498113 * per_privacy_y + 0.598688 * per_gender_y % 0.426673 * nFriends_y % 0.548239 * cn + 0.245971 * per_homeCity_y % 0.571953 * nFriends_x
# Generation 2: Best fitness 0.7879999999999999, Best expression 0.498113 * per_privacy_y + 0.598688 * per_gender_y % 0.426673 * nFriends_y % 0.548239 * cn + 0.245971 * per_homeCity_y % 0.571953 * nFriends_x
# Generation 3: Best fitness 0.7909999999999999, Best expression 0.179188 * cn + 0.2536 * cn % 0.015116 * per_gender_y * 0.441305 * per_homeProvince_y // 0.442413 * per_location_y % 0.084673 * cn
# Generation 4: Best fitness 0.792, Best expression 0.681094 * cn * 0.758735 * per_homeProvince_y / 0.969575 * per_homeProvince_y % 0.333063 * 0.810825 * nFriends_y % 0.227484 * cn
# Generation 5: Best fitness 0.792, Best expression 0.681094 * cn * 0.758735 * per_homeProvince_y / 0.969575 * per_homeProvince_y % 0.333063 * 0.810825 * nFriends_y % 0.227484 * cn
# Generation 6: Best fitness 0.797, Best expression 0.82825 * cn + 0.687739 * 0.40533 * nFriends_y % 0.769128 * cn + 0.1061 * per_fName_y * 0.922154 * cn % 0.285608 ** nFriends_y % 0.892666 * cn
# Generation 7: Best fitness 0.798, Best expression 0.525538 * 0.3094 * nFriends_y % 0.355504 * 0.40533 * nFriends_y % 0.769128 * cn + 0.1061 * per_fName_y * 0.922154 * cn % 0.285608 ** nFriends_y % 0.892666 * cn
# Generation 8: Best fitness 0.8049999999999999, Best expression 0.871578 * cn * nFriends_y % 0.355504 * 0.40533 * nFriends_y % 0.769128 * cn + 0.1061 * per_fName_y * 0.922154 * cn % 0.285608 ** nFriends_y % 0.892666 * cn
# Generation 9: Best fitness 0.8049999999999999, Best expression 0.871578 * cn * nFriends_y % 0.355504 * 0.40533 * nFriends_y % 0.769128 * cn + 0.1061 * per_fName_y * 0.922154 * cn % 0.285608 ** nFriends_y % 0.892666 * cn
# Generation 10: Best fitness 0.8049999999999999, Best expression 0.871578 * cn * nFriends_y % 0.355504 * 0.40533 * nFriends_y % 0.769128 * cn + 0.1061 * per_fName_y * 0.922154 * cn % 0.285608 ** nFriends_y % 0.892666 * cn
# Generation 11: Best fitness 0.8109999999999999, Best expression 0.638757 * cn - 0.453751 - nFriends_y + 0.40533 * nFriends_y % 0.769128 * cn + 0.1061 * per_fName_y / 0.922154 * cn % 0.285608 ** nFriends_y % 0.892666 * cn
# Generation 12: Best fitness 0.8109999999999999, Best expression 0.638757 * cn - 0.453751 - nFriends_y + 0.40533 * nFriends_y % 0.769128 * cn + 0.1061 * per_fName_y / 0.922154 * cn % 0.285608 ** nFriends_y % 0.892666 * cn
# Generation 13: Best fitness 0.8109999999999999, Best expression 0.638757 * cn - 0.453751 - nFriends_y + 0.40533 * nFriends_y % 0.769128 * cn + 0.1061 * per_fName_y / 0.922154 * cn % 0.285608 ** nFriends_y % 0.892666 * cn
# Generation 14: Best fitness 0.8109999999999999, Best expression 0.638757 * cn - 0.453751 - nFriends_y + 0.40533 * nFriends_y % 0.769128 * cn + 0.1061 * per_fName_y / 0.922154 * cn % 0.285608 ** nFriends_y % 0.892666 * cn
# Generation 15: Best fitness 0.8109999999999999, Best expression 0.638757 * cn - 0.453751 - nFriends_y + 0.40533 * nFriends_y % 0.769128 * cn + 0.1061 * per_fName_y / 0.922154 * cn % 0.285608 ** nFriends_y % 0.892666 * cn
# Generation 16: Best fitness 0.8109999999999999, Best expression 0.638757 * cn - 0.453751 - nFriends_y + 0.40533 * nFriends_y % 0.769128 * cn + 0.1061 * per_fName_y / 0.922154 * cn % 0.285608 ** nFriends_y % 0.892666 * cn
# Generation 17: Best fitness 0.8124999999999999, Best expression 0.88076 + cn + 0.2688 * nFriends_x * per_fName_y + 0.754859 * per_location_y % 0.548239 * cn + nFriends_y % 0.548239 * 0.2593 * cn * nFriends_y * 0.285608 % nFriends_y % 0.892666 * cn
# Generation 18: Best fitness 0.814, Best expression 0.88076 + cn + 0.2688 * nFriends_x * per_fName_y + 0.754859 * per_location_y % 0.548239 * cn + 0.0743 * nFriends_x * 0.9259 * per_homeProvince_y % 0.285608 * nFriends_y % 0.892666 * 0.892666 * cn
# Generation 19: Best fitness 0.8164999999999999, Best expression 0.551952 // per_privacy_y + cn + 0.849059 % nFriends_x + 0.754859 * 0.6489 * cn % 0.548239 * cn + 0.1045 * cn * per_location_y % 0.922154 * 0.285608 ** 0.285608 * 0.1624 * nFriends_y % nFriends_y % 0.892666 * cn
# Generation 20: Best fitness 0.8219999999999998, Best expression 0.9571 * per_privacy_y * cn + 0.849059 + per_location_y % 0.725102 * cn + 0.456581 * 0.426673 * nFriends_y // 0.439722 * 0.807417 * 0.227484 * per_location_y % 0.285608 + nFriends_y % 0.892666 * 0.892666 * cn
# Generation 21: Best fitness 0.8219999999999998, Best expression 0.9571 * per_privacy_y * cn + 0.849059 + per_location_y % 0.725102 * cn + 0.456581 * 0.426673 * nFriends_y // 0.439722 * 0.807417 * 0.227484 * per_location_y % 0.285608 + nFriends_y % 0.892666 * 0.892666 * cn
# Generation 22: Best fitness 0.8219999999999998, Best expression 0.9571 * per_privacy_y * cn + 0.849059 + per_location_y % 0.725102 * cn + 0.456581 * 0.426673 * nFriends_y // 0.439722 * 0.807417 * 0.227484 * per_location_y % 0.285608 + nFriends_y % 0.892666 * 0.892666 * cn
# Generation 23: Best fitness 0.8219999999999998, Best expression 0.9571 * per_privacy_y * cn + 0.849059 + per_location_y % 0.725102 * cn + 0.456581 * 0.426673 * nFriends_y // 0.439722 * 0.807417 * 0.227484 * per_location_y % 0.285608 + nFriends_y % 0.892666 * 0.892666 * cn
# Generation 24: Best fitness 0.8219999999999998, Best expression 0.9571 * per_privacy_y * cn + 0.849059 + per_location_y % 0.725102 * cn + 0.456581 * 0.426673 * nFriends_y // 0.439722 * 0.807417 * 0.227484 * per_location_y % 0.285608 + nFriends_y % 0.892666 * 0.892666 * cn
# Generation 25: Best fitness 0.8264999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y % 0.285608 * 0.285608 ** per_location_y * per_location_y % 0.285608 * nFriends_y % 0.892666 * cn
# Generation 26: Best fitness 0.8264999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y % 0.285608 * 0.285608 ** per_location_y * per_location_y % 0.285608 * nFriends_y % 0.892666 * cn
# Generation 27: Best fitness 0.8264999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y % 0.285608 * 0.285608 ** per_location_y * per_location_y % 0.285608 * nFriends_y % 0.892666 * cn
# Generation 28: Best fitness 0.8264999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y % 0.285608 * 0.285608 ** per_location_y * per_location_y % 0.285608 * nFriends_y % 0.892666 * cn
# Generation 29: Best fitness 0.8264999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y % 0.285608 * 0.285608 ** per_location_y * per_location_y % 0.285608 * nFriends_y % 0.892666 * cn
# Generation 30: Best fitness 0.8264999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y % 0.285608 * 0.285608 ** per_location_y * per_location_y % 0.285608 * nFriends_y % 0.892666 * cn
# Generation 31: Best fitness 0.828, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y + 0.0541 * per_homeCity_y / per_location_y * nFriends_x + cn * per_homeCity_y % nFriends_y % 0.9816 % nFriends_x * nFriends_y % 0.892666 * nFriends_y % 0.892666 * 0.892666 * 0.892666 * cn
# Generation 32: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 33: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 34: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 35: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 36: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 37: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 38: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 39: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 40: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 41: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 42: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 43: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 44: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 45: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 46: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 47: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 48: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 49: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 50: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 51: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 52: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 53: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 54: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 55: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 56: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 57: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 58: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 59: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 60: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 61: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 62: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 63: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 64: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 65: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 66: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 67: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 68: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 69: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 70: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 71: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 72: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 73: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 74: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 75: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 76: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 77: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 78: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 79: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 80: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 81: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 82: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 83: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 84: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 85: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 86: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 87: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 88: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 89: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# Generation 90: Best fitness 0.8294999999999999, Best expression 0.9571 * per_privacy_y * cn + per_location_y % 0.725102 * cn + 0.233987 * 0.2355 * per_gender_y * cn + 0.3094 * 0.2898 * per_location_y * per_homeProvince_y * per_location_y / 0.2749 % 0.285608 + per_location_y * 0.3756 * nFriends_x % nFriends_y % 0.892666 * 0.892666 * cn
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 103
#     100     return best_expr
#     102 columns = ['nFriends_x', 'nFriends_y', 'cn', 'per_fName_y', 'per_gender_y', 'per_homeCity_y', 'per_location_y', 'per_privacy_y', 'per_homeProvince_y']
# --> 103 best_expression = genetic_algorithm(df10_standardized, columns, population_size=15000, num_generations=400, num_parents=1500, mutation_rate=0.65)
#     104 print('Best Expression:', best_expression)
#
# Cell In[1], line 81, in genetic_algorithm(df, columns, population_size, num_generations, num_parents, mutation_rate)
#      76 population = generate_initial_population(population_size, columns)
#      78 for generation in range(num_generations):
#      79     #fitnesses = [nget_average_pAT10(df, expr) for expr in population]
#      80     #fitnesses = [fget_average_pAT10(df, expr) for expr in population]
# ---> 81     fitnesses = [nnget_average_pAT10(df, expr) for expr in population]
#      82     max_index = fitnesses.index(max(fitnesses))
#      83     best_expr = population[max_index]
#
# Cell In[1], line 81, in <listcomp>(.0)
#      76 population = generate_initial_population(population_size, columns)
#      78 for generation in range(num_generations):
#      79     #fitnesses = [nget_average_pAT10(df, expr) for expr in population]
#      80     #fitnesses = [fget_average_pAT10(df, expr) for expr in population]
# ---> 81     fitnesses = [nnget_average_pAT10(df, expr) for expr in population]
#      82     max_index = fitnesses.index(max(fitnesses))
#      83     best_expr = population[max_index]
#
# Cell In[1], line 26, in nnget_average_pAT10(df, factor_expression)
#      24 # 计算pAT5
#      25 pAT5 = (top10_per_user.groupby('userID').head(5)['change'] == 1).groupby(top10_per_user['userID']).sum() / 5
# ---> 26 all_users_pAT5 = pAT5.reindex(df['userID'].unique(), fill_value=0)
#      27 avg_pAT5 = all_users_pAT5.mean()
#      28 # 计算pAT10
#
# File ~/miniconda3/envs/rapids-24.02/lib/python3.9/site-packages/nvtx/nvtx.py:116, in annotate.__call__.<locals>.inner(*args, **kwargs)
#     113 @wraps(func)
#     114 def inner(*args, **kwargs):
#     115     libnvtx_push_range(self.attributes, self.domain.handle)
# --> 116     result = func(*args, **kwargs)
#     117     libnvtx_pop_range(self.domain.handle)
#     118     return result
#
# File ~/miniconda3/envs/rapids-24.02/lib/python3.9/site-packages/cudf/core/series.py:1101, in Series.reindex(self, *args, **kwargs)
#    1098     index = kwargs.get("index", self._index)
#    1100 name = self.name or 0
# -> 1101 series = self._reindex(
#    1102     deep=kwargs.get("copy", True),
#    1103     dtypes={name: self.dtype},
#    1104     index=index,
#    1105     column_names=[name],
#    1106     inplace=False,
#    1107     fill_value=kwargs.get("fill_value", cudf.NA),
#    1108 )
#    1109 series.name = self.name
#    1110 return series
#
# File ~/miniconda3/envs/rapids-24.02/lib/python3.9/site-packages/nvtx/nvtx.py:116, in annotate.__call__.<locals>.inner(*args, **kwargs)
#     113 @wraps(func)
#     114 def inner(*args, **kwargs):
#     115     libnvtx_push_range(self.attributes, self.domain.handle)
# --> 116     result = func(*args, **kwargs)
#     117     libnvtx_pop_range(self.domain.handle)
#     118     return result
#
# File ~/miniconda3/envs/rapids-24.02/lib/python3.9/site-packages/cudf/core/indexed_frame.py:2649, in IndexedFrame._reindex(self, column_names, dtypes, deep, index, inplace, fill_value)
#    2646     multiindex = False
#    2647     rangeindex = False
# -> 2649 cols = {
#    2650     name: (
#    2651         df._data[name].copy(deep=deep)
#    2652         if name in df._data
#    2653         else cudf.core.column.column.column_empty(
#    2654             dtype=dtypes.get(name, np.float64),
#    2655             masked=True,
#    2656             row_count=len(index),
#    2657         )
#    2658     )
#    2659     for name in names
#    2660 }
#    2662 result = self.__class__._from_data(
#    2663     data=cudf.core.column_accessor.ColumnAccessor(
#    2664         cols,
#    (...)
#    2669     index=index,
#    2670 )
#    2672 result.fillna(fill_value, inplace=True)
#
# File ~/miniconda3/envs/rapids-24.02/lib/python3.9/site-packages/cudf/core/indexed_frame.py:2651, in <dictcomp>(.0)
#    2646     multiindex = False
#    2647     rangeindex = False
#    2649 cols = {
#    2650     name: (
# -> 2651         df._data[name].copy(deep=deep)
#    2652         if name in df._data
#    2653         else cudf.core.column.column.column_empty(
#    2654             dtype=dtypes.get(name, np.float64),
#    2655             masked=True,
#    2656             row_count=len(index),
#    2657         )
#    2658     )
#    2659     for name in names
#    2660 }
#    2662 result = self.__class__._from_data(
#    2663     data=cudf.core.column_accessor.ColumnAccessor(
#    2664         cols,
#    (...)
#    2669     index=index,
#    2670 )
#    2672 result.fillna(fill_value, inplace=True)
#
# File ~/miniconda3/envs/rapids-24.02/lib/python3.9/site-packages/cudf/core/column/column.py:450, in ColumnBase.copy(self, deep)
#     432 """
#     433 Makes a copy of the Column.
#     434
#    (...)
#     447     them.
#     448 """
#     449 if deep:
# --> 450     result = libcudf.copying.copy_column(self)
#     451     return result._with_type_metadata(self.dtype)
#     452 else:
#
# File ~/miniconda3/envs/rapids-24.02/lib/python3.9/contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File copying.pyx:79, in cudf._lib.copying.copy_column()
#
# File column.pyx:564, in cudf._lib.column.Column.from_unique_ptr()
#
# File device_buffer.pyx:169, in rmm._lib.device_buffer.DeviceBuffer.c_from_unique_ptr()
#
# File memory_resource.pyx:1089, in rmm._lib.memory_resource.get_current_device_resource()
#
# File ~/miniconda3/envs/rapids-24.02/lib/python3.9/site-packages/rmm/_cuda/gpu.py:52, in getDevice()
#      48         raise CUDARuntimeError(status)
#      49     return version
# ---> 52 def getDevice():
#      53     """
#      54     Get the current CUDA device
#      55     """
#      56     status, device = cudart.cudaGetDevice()
#
# KeyboardInterrupt:

# %%
import random
import cudf as pd
import cupy as np
df10_standardized = pd.read_csv("cudf.csv", sep='\t')
df10_truth= pd.read_csv("cudf_tru20_al.csv", sep='\t')

def get_pAT(df, factor_expression, weight_pAT5=0.7, weight_pAT10=0.3):
    df['factor_value'] = df.eval(factor_expression)
    sorted_df = df.sort_values(['userID', 'factor_value'], ascending=[True, False])
    top10_per_user = sorted_df.groupby('userID').head(10)
    top10_per_user['relevant'] = top10_per_user['isFriend']
    user_relevant_counts = top10_per_user.groupby('userID')['relevant'].sum().reset_index(name='relevant_count')
    user_relevant_counts['pAT5'] = user_relevant_counts['relevant_count'].clip(upper=5) / 5.0
    user_relevant_counts['pAT10'] = user_relevant_counts['relevant_count'] / 10.0
    average_pAT = (user_relevant_counts['pAT5'] * weight_pAT5 + user_relevant_counts['pAT10'] * weight_pAT10).mean()
    return average_pAT

def nnget_average_pAT10(df, factor_expression):
    df['factor_value'] = df.eval(factor_expression)
    isFriend_zero_df = df[df['isFriend'] == 0]
    top10_per_user = isFriend_zero_df.sort_values(['userID', 'factor_value'], ascending=[True, False]).groupby('userID').head(10)
    pAT5 = (top10_per_user.groupby('userID').head(5)['change'] == 1).groupby(top10_per_user['userID']).sum() / 5
    all_users_pAT5 = pAT5.reindex(df['userID'].unique(), fill_value=0)
    avg_pAT5 = all_users_pAT5.mean()
    pAT10 = (top10_per_user['change'] == 1).groupby(top10_per_user['userID']).sum() / 10
    all_users_pAT10 = pAT10.reindex(df['userID'].unique(), fill_value=0)
    avg_pAT10 = all_users_pAT10.mean()
    return avg_pAT5, avg_pAT10

def fitness_function(df_standardized, df_truth, factor_expression):
    avg_pAT1 = get_pAT(df_standardized, factor_expression)
    avg_pAT5, avg_pAT10 = nnget_average_pAT10(df_truth, factor_expression)
    avg_pAT2 = ((0.7 * avg_pAT5) + (0.3 * avg_pAT10))*0.95
    return (0.7 * avg_pAT1) + (0.3 * avg_pAT2)

def generate_initial_population(size, columns):
    population = []
    operators = ['+', '-', '*', '/','%','//','**']
    for _ in range(size):
        const_factor = round(random.uniform(0, 1), 6)
        expr = f"{const_factor} * {random.choice(columns)}"
        for _ in range(random.randint(1, 7)):  # Generate expressions with depth between 1 and 5
            const_factor = round(random.uniform(0, 1), 6)
            expr += f" {random.choice(operators)} {const_factor} * {random.choice(columns)}"
        population.append(expr)
    return population


def select(population, fitnesses, num_parents):
    parents = sorted(zip(population, fitnesses), key=lambda x: x[1], reverse=True)[:num_parents]
    return [expr for expr, _ in parents]

def crossover(parent1, parent2):
    parts1 = parent1.split(' ')
    parts2 = parent2.split(' ')
    if len(parts1) > 1 and len(parts2) > 1:
        crossover_point = random.randint(1, min(len(parts1), len(parts2)) - 1)
        child = ' '.join(parts1[:crossover_point] + parts2[crossover_point:])
        return child
    return parent1

def mutate(expression, columns, mutation_rate=0.1):
    parts = expression.split(' ')
    if random.random() < mutation_rate:
        index = random.randint(0, len(parts) - 1)
        if index % 2 == 0:
            const_factor = round(random.uniform(0, 1), 4)
            parts[index] = f"{const_factor} * {random.choice(columns)}"
        else:
            parts[index] = random.choice(['+', '-', '*', '/','%','//','**'])
    return ' '.join(parts)


def genetic_algorithm(df_standardized, df_truth, columns, population_size, num_generations, num_parents, mutation_rate):
    population = generate_initial_population(population_size, columns)
    for generation in range(num_generations):
        fitnesses = [fitness_function(df_standardized, df_truth, expr) for expr in population]
        max_index = fitnesses.index(max(fitnesses))
        best_expr = population[max_index]
        best_fitness = fitnesses[max_index]
        print(f'Generation {generation + 1}: Best fitness {best_fitness}, Best expression {best_expr}')

        parents = select(population, fitnesses, num_parents)
        next_population = parents[:2]  # Keep the best individuals

        while len(next_population) < population_size:
            parent1, parent2 = random.sample(parents, 2)
            child = crossover(parent1, parent2)
            child = mutate(child, columns, mutation_rate)
            next_population.append(child)
        population = next_population
    best_expr = select(population, [fitness_function(df_standardized, df_truth, expr) for expr in population], 1)[0]
    return best_expr

columns = ['nFriends_x', 'nFriends_y', 'cn', 'per_fName_y', 'per_gender_y', 'per_homeCity_y', 'per_location_y', 'per_privacy_y', 'per_homeProvince_y']
best_expression = genetic_algorithm(df10_standardized, df10_truth, columns, population_size=520, num_generations=1000, num_parents=52, mutation_rate=0.4)
print('Best Expression:', best_expression)
# Out:
# Generation 1: Best fitness 0.7938268595041322, Best expression 0.221718 * cn + 0.543768 * per_privacy_y
# Generation 2: Best fitness 0.7975004132231405, Best expression 0.49676 * per_location_y % 0.430454 * cn + 0.7661 + cn
# Generation 3: Best fitness 0.801490909090909, Best expression 0.17463 * 0.662 * per_fName_y + 0.952888 * cn
# Generation 4: Best fitness 0.8038987603305785, Best expression 0.221718 * cn + 0.898039 * cn + 0.0575 * cn * per_homeCity_y + 0.636472 * per_privacy_y
# Generation 5: Best fitness 0.8062681818181817, Best expression 0.396713 * cn + 0.537553 * per_fName_y * 0.082127 * cn
# Generation 6: Best fitness 0.8128111570247931, Best expression 0.627792 * cn + 0.278125 * cn + 0.119332 * per_homeCity_y + 0.7892 * per_location_y * 0.0054 + per_privacy_y + 0.087997 * 0.6942 * per_fName_y
# Generation 7: Best fitness 0.8133607438016527, Best expression 0.627792 * cn + 0.278125 % cn + 0.119332 * per_homeCity_y + 0.636472 * 0.0054 + per_privacy_y + 0.087997 * 0.6942 * per_fName_y
# Generation 8: Best fitness 0.8175999999999999, Best expression 0.396713 * cn + 0.278125 * 0.1938 * per_location_y + 0.119332 * per_homeCity_y + 0.636472 * 0.0054 + per_privacy_y + 0.087997 * 0.6942 * per_fName_y
# Generation 9: Best fitness 0.819145867768595, Best expression 0.396713 * cn + 0.278125 * 0.1938 * per_location_y + 0.119332 * per_homeCity_y + 0.636472 * 0.0054 + per_privacy_y + 0.087997 % 0.686724 * 0.3365 * per_fName_y
# Generation 10: Best fitness 0.819145867768595, Best expression 0.396713 * cn + 0.278125 * 0.1938 * per_location_y + 0.119332 * per_homeCity_y + 0.636472 * 0.0054 + per_privacy_y + 0.087997 % 0.686724 * 0.3365 * per_fName_y
# Generation 11: Best fitness 0.8246644628099173, Best expression 0.618796 * cn + 0.14361 * 0.8002 * per_location_y + 0.119332 * per_homeCity_y + 0.636472 * 0.0054 + per_privacy_y + 0.087997 * 0.6942 % per_fName_y
# Generation 12: Best fitness 0.8253297520661156, Best expression 0.627792 * cn + 0.537553 * 0.1938 * per_location_y + 0.119332 * per_homeCity_y + 0.636472 * 0.0054 + per_privacy_y + 0.087997 * 0.6942 % per_fName_y
# Generation 13: Best fitness 0.8253297520661156, Best expression 0.627792 * cn + 0.537553 * 0.1938 * per_location_y + 0.119332 * per_homeCity_y + 0.636472 * 0.0054 + per_privacy_y + 0.087997 * 0.6942 % per_fName_y
# Generation 14: Best fitness 0.8253297520661156, Best expression 0.627792 * cn + 0.537553 * 0.1938 * per_location_y + 0.119332 * per_homeCity_y + 0.636472 * 0.0054 + per_privacy_y + 0.087997 * 0.6942 % per_fName_y
# Generation 15: Best fitness 0.8253297520661156, Best expression 0.627792 * cn + 0.537553 * 0.1938 * per_location_y + 0.119332 * per_homeCity_y + 0.636472 * 0.0054 + per_privacy_y + 0.087997 * 0.6942 % per_fName_y
# Generation 16: Best fitness 0.8253297520661156, Best expression 0.627792 * cn + 0.537553 * 0.1938 * per_location_y + 0.119332 * per_homeCity_y + 0.636472 * 0.0054 + per_privacy_y + 0.087997 * 0.6942 % per_fName_y
# Generation 17: Best fitness 0.8253297520661156, Best expression 0.627792 * cn + 0.537553 * 0.1938 * per_location_y + 0.119332 * per_homeCity_y + 0.636472 * 0.0054 + per_privacy_y + 0.087997 * 0.6942 % per_fName_y
# Generation 18: Best fitness 0.8253297520661156, Best expression 0.627792 * cn + 0.537553 * 0.1938 * per_location_y + 0.119332 * per_homeCity_y + 0.636472 * 0.0054 + per_privacy_y + 0.087997 * 0.6942 % per_fName_y
# Generation 19: Best fitness 0.8256706611570246, Best expression 0.627792 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 * per_homeCity_y + 0.636472 * 0.0054 + per_privacy_y + 0.087997 * 0.6942 % per_fName_y
# Generation 20: Best fitness 0.8256706611570246, Best expression 0.627792 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 * per_homeCity_y + 0.636472 * 0.0054 + per_privacy_y + 0.087997 * 0.6942 % per_fName_y
# Generation 21: Best fitness 0.8261123966942148, Best expression 0.627792 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 * per_homeCity_y + 0.0463 * per_location_y + cn + per_privacy_y + 0.087997 * 0.6942 % per_fName_y
# Generation 22: Best fitness 0.8273483471074379, Best expression 0.627792 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 * per_homeCity_y + 0.636472 * 0.0054 + per_privacy_y + per_privacy_y + 0.087997 * 0.6942 % per_fName_y
# Generation 23: Best fitness 0.8277533057851238, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 * per_homeCity_y + 0.636472 // 0.0054 + per_privacy_y + per_privacy_y + 0.087997 * 0.6942 % per_fName_y
# Generation 24: Best fitness 0.8278400826446282, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 * per_homeCity_y + 0.636472 * 0.0054 + per_privacy_y + per_privacy_y + 0.087997 * 0.6942 % 0.6942 % per_fName_y
# Generation 25: Best fitness 0.8283632231404956, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 * per_homeCity_y + 0.636472 * 0.4998 * per_homeCity_y + per_privacy_y + per_privacy_y + 0.087997 * 0.6942 % per_fName_y
# Generation 26: Best fitness 0.830530165289256, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 * per_homeCity_y + 0.636472 // 0.0054 * per_privacy_y + per_privacy_y + 0.087997 * 0.6942 % per_fName_y
# Generation 27: Best fitness 0.830530165289256, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 * per_homeCity_y + 0.636472 // 0.0054 * per_privacy_y + per_privacy_y + 0.087997 * 0.6942 % per_fName_y
# Generation 28: Best fitness 0.8370012396694213, Best expression 0.627792 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * per_gender_y + per_privacy_y + per_privacy_y + per_privacy_y + 0.087997 * 0.6942 * 0.3365 % per_fName_y
# Generation 29: Best fitness 0.8370012396694213, Best expression 0.627792 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * per_gender_y + per_privacy_y + per_privacy_y + per_privacy_y + 0.087997 * 0.6942 * 0.3365 % per_fName_y
# Generation 30: Best fitness 0.8370012396694213, Best expression 0.627792 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * per_gender_y + per_privacy_y + per_privacy_y + per_privacy_y + 0.087997 * 0.6942 * 0.3365 % per_fName_y
# Generation 31: Best fitness 0.8370012396694213, Best expression 0.627792 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * per_gender_y + per_privacy_y + per_privacy_y + per_privacy_y + 0.087997 * 0.6942 * 0.3365 % per_fName_y
# Generation 32: Best fitness 0.8370880165289254, Best expression 0.627792 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * per_gender_y + per_privacy_y + 0.6273 * per_privacy_y + per_privacy_y + 0.087997 * 0.6942 * 0.3365 % per_fName_y
# Generation 33: Best fitness 0.8370880165289254, Best expression 0.627792 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * per_gender_y + per_privacy_y + 0.6273 * per_privacy_y + per_privacy_y + 0.087997 * 0.6942 * 0.3365 % per_fName_y
# Generation 34: Best fitness 0.8370880165289254, Best expression 0.627792 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * per_gender_y + per_privacy_y + 0.6273 * per_privacy_y + per_privacy_y + 0.087997 * 0.6942 * 0.3365 % per_fName_y
# Generation 35: Best fitness 0.8370880165289254, Best expression 0.627792 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * per_gender_y + per_privacy_y + 0.6273 * per_privacy_y + per_privacy_y + 0.087997 * 0.6942 * 0.3365 % per_fName_y
# Generation 36: Best fitness 0.8370880165289254, Best expression 0.627792 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * per_gender_y + per_privacy_y + 0.6273 * per_privacy_y + per_privacy_y + 0.087997 * 0.6942 * 0.3365 % per_fName_y
# Generation 37: Best fitness 0.8377545454545453, Best expression 0.627792 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * per_gender_y + per_privacy_y + 0.6273 * per_privacy_y + per_privacy_y + 0.087997 * 0.6942 * 0.3365 % per_fName_y
# Generation 38: Best fitness 0.8377545454545453, Best expression 0.627792 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * per_gender_y + per_privacy_y + 0.6273 * per_privacy_y + per_privacy_y + 0.087997 * 0.6942 * 0.3365 % per_fName_y
# Generation 39: Best fitness 0.8377545454545453, Best expression 0.627792 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * per_gender_y + per_privacy_y + 0.6273 * per_privacy_y + per_privacy_y + 0.087997 * 0.6942 * 0.3365 % per_fName_y
# Generation 40: Best fitness 0.8377545454545453, Best expression 0.627792 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * per_gender_y + per_privacy_y + 0.6273 * per_privacy_y + per_privacy_y + 0.087997 * 0.6942 * 0.3365 % per_fName_y
# Generation 41: Best fitness 0.8377545454545453, Best expression 0.627792 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * per_gender_y + per_privacy_y + 0.6273 * per_privacy_y + per_privacy_y + 0.087997 * 0.6942 * 0.3365 % per_fName_y
# Generation 42: Best fitness 0.8377545454545453, Best expression 0.627792 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * per_gender_y + per_privacy_y + 0.6273 * per_privacy_y + per_privacy_y + 0.087997 * 0.6942 * 0.3365 % per_fName_y
# Generation 43: Best fitness 0.8381595041322312, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * per_gender_y + per_privacy_y // 0.6273 % per_privacy_y + per_privacy_y + 0.087997 * 0.3365 % 0.3365 % per_fName_y
# Generation 44: Best fitness 0.8381595041322312, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * per_gender_y + per_privacy_y // 0.6273 % per_privacy_y + per_privacy_y + 0.087997 * 0.3365 % 0.3365 % per_fName_y
# Generation 45: Best fitness 0.8381595041322312, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * per_gender_y + per_privacy_y // 0.6273 % per_privacy_y + per_privacy_y + 0.087997 * 0.3365 % 0.3365 % per_fName_y
# Generation 46: Best fitness 0.8383330578512395, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * per_gender_y + per_privacy_y // 0.6273 % per_privacy_y + per_privacy_y + per_privacy_y + 0.087997 * 0.3365 % 0.3365 % per_fName_y
# Generation 47: Best fitness 0.8383330578512395, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * per_gender_y + per_privacy_y // 0.6273 % per_privacy_y + per_privacy_y + per_privacy_y + 0.087997 * 0.3365 % 0.3365 % per_fName_y
# Generation 48: Best fitness 0.8385644628099171, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * per_gender_y + per_privacy_y + per_privacy_y // 0.6273 + per_privacy_y + per_privacy_y + 0.087997 * 0.3365 % 0.3365 % per_fName_y
# Generation 49: Best fitness 0.8385644628099171, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * per_gender_y + per_privacy_y + per_privacy_y // 0.6273 + per_privacy_y + per_privacy_y + 0.087997 * 0.3365 % 0.3365 % per_fName_y
# Generation 50: Best fitness 0.8397260330578511, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * per_gender_y + per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 % 0.3365 % per_fName_y
# Generation 51: Best fitness 0.8397260330578511, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * per_gender_y + per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 % 0.3365 % per_fName_y
# Generation 52: Best fitness 0.8397260330578511, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * per_gender_y + per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 % 0.3365 % per_fName_y
# Generation 53: Best fitness 0.8398128099173552, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * per_gender_y + per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 % per_fName_y
# Generation 54: Best fitness 0.8398128099173552, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * per_gender_y + per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 % per_fName_y
# Generation 55: Best fitness 0.8407962809917353, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * per_gender_y + per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * per_gender_y + per_privacy_y + per_privacy_y + 0.087997 * 0.3365 % 0.3365 % per_fName_y
# Generation 56: Best fitness 0.8407962809917353, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * per_gender_y + per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * per_gender_y + per_privacy_y + per_privacy_y + 0.087997 * 0.3365 % 0.3365 % per_fName_y
# Generation 57: Best fitness 0.8407962809917353, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * per_gender_y + per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * per_gender_y + per_privacy_y + per_privacy_y + 0.087997 * 0.3365 % 0.3365 % per_fName_y
# Generation 58: Best fitness 0.8408830578512396, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * per_gender_y + per_privacy_y + per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 % per_fName_y
# Generation 59: Best fitness 0.8408830578512396, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * per_gender_y + per_privacy_y + per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 % per_fName_y
# Generation 60: Best fitness 0.8412301652892561, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y + per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 % per_fName_y
# Generation 61: Best fitness 0.8412301652892561, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y + per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 % per_fName_y
# Generation 62: Best fitness 0.8412301652892561, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y + per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 % per_fName_y
# Generation 63: Best fitness 0.8412301652892561, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y + per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 % per_fName_y
# Generation 64: Best fitness 0.8414454545454543, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y + per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 % per_fName_y
# Generation 65: Best fitness 0.8414454545454543, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y + per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 % per_fName_y
# Generation 66: Best fitness 0.8414454545454543, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y + per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 % per_fName_y
# Generation 67: Best fitness 0.8414454545454543, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y + per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 % per_fName_y
# Generation 68: Best fitness 0.8415322314049585, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y + per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 69: Best fitness 0.8415322314049585, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y + per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 70: Best fitness 0.8415322314049585, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y + per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 71: Best fitness 0.8415322314049585, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y + per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 72: Best fitness 0.8416190082644626, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.6429 * per_privacy_y + per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 73: Best fitness 0.8416190082644626, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.6429 * per_privacy_y + per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 74: Best fitness 0.8416190082644626, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.6429 * per_privacy_y + per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 75: Best fitness 0.8416190082644626, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.6429 * per_privacy_y + per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 76: Best fitness 0.8416190082644626, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.6429 * per_privacy_y + per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 77: Best fitness 0.8416190082644626, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.6429 * per_privacy_y + per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 78: Best fitness 0.8416190082644626, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.6429 * per_privacy_y + per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 79: Best fitness 0.8416190082644626, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.6429 * per_privacy_y + per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 80: Best fitness 0.8419243801652891, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y % 0.6383 * per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 81: Best fitness 0.8419243801652891, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y % 0.6383 * per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 82: Best fitness 0.8419243801652891, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y % 0.6383 * per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 83: Best fitness 0.8419243801652891, Best expression 0.396713 + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y % 0.6383 * per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 84: Best fitness 0.8424289256198346, Best expression 0.5068 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y % 0.6383 * per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 85: Best fitness 0.8424289256198346, Best expression 0.5068 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y % 0.6383 * per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 86: Best fitness 0.8424289256198346, Best expression 0.5068 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y % 0.6383 * per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 87: Best fitness 0.8424289256198346, Best expression 0.5068 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y % 0.6383 * per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 88: Best fitness 0.8424289256198346, Best expression 0.5068 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y % 0.6383 * per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 89: Best fitness 0.8424289256198346, Best expression 0.5068 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y % 0.6383 * per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 90: Best fitness 0.8424289256198346, Best expression 0.5068 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y % 0.6383 * per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 91: Best fitness 0.8424289256198346, Best expression 0.5068 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y % 0.6383 * per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 92: Best fitness 0.8424289256198346, Best expression 0.5068 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y % 0.6383 * per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 93: Best fitness 0.8426764462809917, Best expression 0.2161 * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y % 0.6383 * per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 94: Best fitness 0.8426764462809917, Best expression 0.2161 * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y % 0.6383 * per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 95: Best fitness 0.8427181818181817, Best expression 0.5068 * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y % 0.6383 * per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 96: Best fitness 0.8427181818181817, Best expression 0.5068 * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y % 0.6383 * per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 97: Best fitness 0.8429367768595041, Best expression 0.7661 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y % 0.6383 * per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 % 0.3365 % per_fName_y
# Generation 98: Best fitness 0.8429367768595041, Best expression 0.7661 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y % 0.6383 * per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + per_privacy_y + 0.087997 * 0.3365 * 0.3365 % 0.3365 % per_fName_y
# Generation 99: Best fitness 0.8432293388429752, Best expression 0.7661 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y % 0.6383 * per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 % per_fName_y
# Generation 100: Best fitness 0.8433161157024793, Best expression 0.7661 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y % 0.6383 * per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 101: Best fitness 0.8433161157024793, Best expression 0.7661 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y % 0.6383 * per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 102: Best fitness 0.8433161157024793, Best expression 0.7661 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y % 0.6383 * per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 103: Best fitness 0.8433161157024793, Best expression 0.7661 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y % 0.6383 * per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 104: Best fitness 0.8433161157024793, Best expression 0.7661 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y % 0.6383 * per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 105: Best fitness 0.8433161157024793, Best expression 0.7661 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y % 0.6383 * per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 106: Best fitness 0.8434028925619834, Best expression 0.5068 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y % 0.6383 * per_privacy_y + 0.8948 * per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 107: Best fitness 0.8434028925619834, Best expression 0.5068 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y % 0.6383 * per_privacy_y + 0.8948 * per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 108: Best fitness 0.8434028925619834, Best expression 0.5068 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y % 0.6383 * per_privacy_y + 0.8948 * per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 109: Best fitness 0.8437210743801653, Best expression 0.6242 * 0.9205 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y % 0.6383 * per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % 0.3365 % per_fName_y
# Generation 110: Best fitness 0.8437210743801653, Best expression 0.6242 * 0.9205 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y % 0.6383 * per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % 0.3365 % per_fName_y
# Generation 111: Best fitness 0.8437210743801653, Best expression 0.6242 * 0.9205 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + per_privacy_y % 0.6383 * per_privacy_y + per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % 0.3365 % per_fName_y
# Generation 112: Best fitness 0.8438078512396694, Best expression 0.5068 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.9954 * per_privacy_y % 0.6383 * per_privacy_y + 0.8948 * per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 113: Best fitness 0.8438078512396694, Best expression 0.5068 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.9954 * per_privacy_y % 0.6383 * per_privacy_y + 0.8948 * per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 114: Best fitness 0.8438078512396694, Best expression 0.5068 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.9954 * per_privacy_y % 0.6383 * per_privacy_y + 0.8948 * per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 115: Best fitness 0.8438078512396694, Best expression 0.5068 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.9954 * per_privacy_y % 0.6383 * per_privacy_y + 0.8948 * per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 116: Best fitness 0.8438078512396694, Best expression 0.5068 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.9954 * per_privacy_y % 0.6383 * per_privacy_y + 0.8948 * per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 117: Best fitness 0.8438946280991735, Best expression 0.5068 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.9954 * per_privacy_y % 0.6383 * per_privacy_y + 0.1683 * per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 118: Best fitness 0.8438946280991735, Best expression 0.5068 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.9954 * per_privacy_y % 0.6383 * per_privacy_y + 0.1683 * per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 119: Best fitness 0.8438946280991735, Best expression 0.5068 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.9954 * per_privacy_y % 0.6383 * per_privacy_y + 0.1683 * per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 120: Best fitness 0.8438946280991735, Best expression 0.5068 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.9954 * per_privacy_y % 0.6383 * per_privacy_y + 0.1683 * per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 121: Best fitness 0.8438946280991735, Best expression 0.5068 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.9954 * per_privacy_y % 0.6383 * per_privacy_y + 0.1683 * per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 122: Best fitness 0.8438946280991735, Best expression 0.5068 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.9954 * per_privacy_y % 0.6383 * per_privacy_y + 0.1683 * per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 123: Best fitness 0.8438946280991735, Best expression 0.5068 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.9954 * per_privacy_y % 0.6383 * per_privacy_y + 0.1683 * per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 124: Best fitness 0.8438946280991735, Best expression 0.5068 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.9954 * per_privacy_y % 0.6383 * per_privacy_y + 0.1683 * per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 125: Best fitness 0.8438946280991735, Best expression 0.5068 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.9954 * per_privacy_y % 0.6383 * per_privacy_y + 0.1683 * per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 126: Best fitness 0.8438946280991735, Best expression 0.5068 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.9954 * per_privacy_y % 0.6383 * per_privacy_y + 0.1683 * per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 127: Best fitness 0.8438946280991735, Best expression 0.5068 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.9954 * per_privacy_y % 0.6383 * per_privacy_y + 0.1683 * per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 128: Best fitness 0.8438946280991735, Best expression 0.5068 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.9954 * per_privacy_y % 0.6383 * per_privacy_y + 0.1683 * per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 129: Best fitness 0.8438946280991735, Best expression 0.5068 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.9954 * per_privacy_y % 0.6383 * per_privacy_y + 0.1683 * per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 130: Best fitness 0.8438946280991735, Best expression 0.5068 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.9954 * per_privacy_y % 0.6383 * per_privacy_y + 0.1683 * per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 131: Best fitness 0.8438946280991735, Best expression 0.5068 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.9954 * per_privacy_y % 0.6383 * per_privacy_y + 0.1683 * per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 132: Best fitness 0.8438946280991735, Best expression 0.5068 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.9954 * per_privacy_y % 0.6383 * per_privacy_y + 0.1683 * per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 133: Best fitness 0.8438946280991735, Best expression 0.5068 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.9954 * per_privacy_y % 0.6383 * per_privacy_y + 0.1683 * per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 134: Best fitness 0.8438946280991735, Best expression 0.5068 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.9954 * per_privacy_y % 0.6383 * per_privacy_y + 0.1683 * per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 135: Best fitness 0.8438946280991735, Best expression 0.5068 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.9954 * per_privacy_y % 0.6383 * per_privacy_y + 0.1683 * per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 136: Best fitness 0.8438946280991735, Best expression 0.5068 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.9954 * per_privacy_y % 0.6383 * per_privacy_y + 0.1683 * per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 137: Best fitness 0.8438946280991735, Best expression 0.5068 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.9954 * per_privacy_y % 0.6383 * per_privacy_y + 0.1683 * per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 138: Best fitness 0.8438946280991735, Best expression 0.5068 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.9954 * per_privacy_y % 0.6383 * per_privacy_y + 0.1683 * per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 139: Best fitness 0.8438946280991735, Best expression 0.5068 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.9954 * per_privacy_y % 0.6383 * per_privacy_y + 0.1683 * per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 140: Best fitness 0.8438946280991735, Best expression 0.5068 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.9954 * per_privacy_y % 0.6383 * per_privacy_y + 0.1683 * per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 141: Best fitness 0.8438946280991735, Best expression 0.5068 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.9954 * per_privacy_y % 0.6383 * per_privacy_y + 0.1683 * per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 142: Best fitness 0.8438946280991735, Best expression 0.5068 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.9954 * per_privacy_y % 0.6383 * per_privacy_y + 0.1683 * per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 143: Best fitness 0.8438946280991735, Best expression 0.5068 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.9954 * per_privacy_y % 0.6383 * per_privacy_y + 0.1683 * per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 144: Best fitness 0.8438946280991735, Best expression 0.5068 * nFriends_x * nFriends_x * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * per_gender_y + 0.9954 * per_privacy_y % 0.6383 * per_privacy_y + 0.1683 * per_privacy_y // 0.6273 % 0.1972 * 0.7281 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# ...
# Generation 885: Best fitness 0.8499896694214875, Best expression 0.0073 / per_privacy_y % nFriends_x / 0.89 * nFriends_x * 0.94 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * 0.9039 * 0.9039 * per_gender_y + 0.7889 * per_privacy_y * 0.698 * per_privacy_y * per_privacy_y % 0.6383 / 0.6383 * 0.6943 * per_privacy_y + 0.1683 * 0.7386 ** 0.8809 / per_homeProvince_y // 0.6273 % 0.1972 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 886: Best fitness 0.8499896694214875, Best expression 0.0073 / per_privacy_y % nFriends_x / 0.89 * nFriends_x * 0.94 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * 0.9039 * 0.9039 * per_gender_y + 0.7889 * per_privacy_y * 0.698 * per_privacy_y * per_privacy_y % 0.6383 / 0.6383 * 0.6943 * per_privacy_y + 0.1683 * 0.7386 ** 0.8809 / per_homeProvince_y // 0.6273 % 0.1972 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 887: Best fitness 0.8499896694214875, Best expression 0.0073 / per_privacy_y % nFriends_x / 0.89 * nFriends_x * 0.94 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * 0.9039 * 0.9039 * per_gender_y + 0.7889 * per_privacy_y * 0.698 * per_privacy_y * per_privacy_y % 0.6383 / 0.6383 * 0.6943 * per_privacy_y + 0.1683 * 0.7386 ** 0.8809 / per_homeProvince_y // 0.6273 % 0.1972 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 888: Best fitness 0.8499896694214875, Best expression 0.0073 / per_privacy_y % nFriends_x / 0.89 * nFriends_x * 0.94 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * 0.9039 * 0.9039 * per_gender_y + 0.7889 * per_privacy_y * 0.698 * per_privacy_y * per_privacy_y % 0.6383 / 0.6383 * 0.6943 * per_privacy_y + 0.1683 * 0.7386 ** 0.8809 / per_homeProvince_y // 0.6273 % 0.1972 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 889: Best fitness 0.8499896694214875, Best expression 0.0073 / per_privacy_y % nFriends_x / 0.89 * nFriends_x * 0.94 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * 0.9039 * 0.9039 * per_gender_y + 0.7889 * per_privacy_y * 0.698 * per_privacy_y * per_privacy_y % 0.6383 / 0.6383 * 0.6943 * per_privacy_y + 0.1683 * 0.7386 ** 0.8809 / per_homeProvince_y // 0.6273 % 0.1972 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 890: Best fitness 0.8499896694214875, Best expression 0.0073 / per_privacy_y % nFriends_x / 0.89 * nFriends_x * 0.94 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * 0.9039 * 0.9039 * per_gender_y + 0.7889 * per_privacy_y * 0.698 * per_privacy_y * per_privacy_y % 0.6383 / 0.6383 * 0.6943 * per_privacy_y + 0.1683 * 0.7386 ** 0.8809 / per_homeProvince_y // 0.6273 % 0.1972 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 891: Best fitness 0.8499896694214875, Best expression 0.0073 / per_privacy_y % nFriends_x / 0.89 * nFriends_x * 0.94 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * 0.9039 * 0.9039 * per_gender_y + 0.7889 * per_privacy_y * 0.698 * per_privacy_y * per_privacy_y % 0.6383 / 0.6383 * 0.6943 * per_privacy_y + 0.1683 * 0.7386 ** 0.8809 / per_homeProvince_y // 0.6273 % 0.1972 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 892: Best fitness 0.8499896694214875, Best expression 0.0073 / per_privacy_y % nFriends_x / 0.89 * nFriends_x * 0.94 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * 0.9039 * 0.9039 * per_gender_y + 0.7889 * per_privacy_y * 0.698 * per_privacy_y * per_privacy_y % 0.6383 / 0.6383 * 0.6943 * per_privacy_y + 0.1683 * 0.7386 ** 0.8809 / per_homeProvince_y // 0.6273 % 0.1972 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 893: Best fitness 0.8499896694214875, Best expression 0.0073 / per_privacy_y % nFriends_x / 0.89 * nFriends_x * 0.94 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * 0.9039 * 0.9039 * per_gender_y + 0.7889 * per_privacy_y * 0.698 * per_privacy_y * per_privacy_y % 0.6383 / 0.6383 * 0.6943 * per_privacy_y + 0.1683 * 0.7386 ** 0.8809 / per_homeProvince_y // 0.6273 % 0.1972 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 894: Best fitness 0.8499896694214875, Best expression 0.0073 / per_privacy_y % nFriends_x / 0.89 * nFriends_x * 0.94 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * 0.9039 * 0.9039 * per_gender_y + 0.7889 * per_privacy_y * 0.698 * per_privacy_y * per_privacy_y % 0.6383 / 0.6383 * 0.6943 * per_privacy_y + 0.1683 * 0.7386 ** 0.8809 / per_homeProvince_y // 0.6273 % 0.1972 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 895: Best fitness 0.8499896694214875, Best expression 0.0073 / per_privacy_y % nFriends_x / 0.89 * nFriends_x * 0.94 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * 0.9039 * 0.9039 * per_gender_y + 0.7889 * per_privacy_y * 0.698 * per_privacy_y * per_privacy_y % 0.6383 / 0.6383 * 0.6943 * per_privacy_y + 0.1683 * 0.7386 ** 0.8809 / per_homeProvince_y // 0.6273 % 0.1972 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 896: Best fitness 0.8499896694214875, Best expression 0.0073 / per_privacy_y % nFriends_x / 0.89 * nFriends_x * 0.94 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * 0.9039 * 0.9039 * per_gender_y + 0.7889 * per_privacy_y * 0.698 * per_privacy_y * per_privacy_y % 0.6383 / 0.6383 * 0.6943 * per_privacy_y + 0.1683 * 0.7386 ** 0.8809 / per_homeProvince_y // 0.6273 % 0.1972 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 897: Best fitness 0.8499896694214875, Best expression 0.0073 / per_privacy_y % nFriends_x / 0.89 * nFriends_x * 0.94 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * 0.9039 * 0.9039 * per_gender_y + 0.7889 * per_privacy_y * 0.698 * per_privacy_y * per_privacy_y % 0.6383 / 0.6383 * 0.6943 * per_privacy_y + 0.1683 * 0.7386 ** 0.8809 / per_homeProvince_y // 0.6273 % 0.1972 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 898: Best fitness 0.8499896694214875, Best expression 0.0073 / per_privacy_y % nFriends_x / 0.89 * nFriends_x * 0.94 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * 0.9039 * 0.9039 * per_gender_y + 0.7889 * per_privacy_y * 0.698 * per_privacy_y * per_privacy_y % 0.6383 / 0.6383 * 0.6943 * per_privacy_y + 0.1683 * 0.7386 ** 0.8809 / per_homeProvince_y // 0.6273 % 0.1972 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 899: Best fitness 0.8499896694214875, Best expression 0.0073 / per_privacy_y % nFriends_x / 0.89 * nFriends_x * 0.94 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * 0.9039 * 0.9039 * per_gender_y + 0.7889 * per_privacy_y * 0.698 * per_privacy_y * per_privacy_y % 0.6383 / 0.6383 * 0.6943 * per_privacy_y + 0.1683 * 0.7386 ** 0.8809 / per_homeProvince_y // 0.6273 % 0.1972 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 900: Best fitness 0.8499896694214875, Best expression 0.0073 / per_privacy_y % nFriends_x / 0.89 * nFriends_x * 0.94 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * 0.9039 * 0.9039 * per_gender_y + 0.7889 * per_privacy_y * 0.698 * per_privacy_y * per_privacy_y % 0.6383 / 0.6383 * 0.6943 * per_privacy_y + 0.1683 * 0.7386 ** 0.8809 / per_homeProvince_y // 0.6273 % 0.1972 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 901: Best fitness 0.8499896694214875, Best expression 0.0073 / per_privacy_y % nFriends_x / 0.89 * nFriends_x * 0.94 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * 0.9039 * 0.9039 * per_gender_y + 0.7889 * per_privacy_y * 0.698 * per_privacy_y * per_privacy_y % 0.6383 / 0.6383 * 0.6943 * per_privacy_y + 0.1683 * 0.7386 ** 0.8809 / per_homeProvince_y // 0.6273 % 0.1972 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 902: Best fitness 0.8499896694214875, Best expression 0.0073 / per_privacy_y % nFriends_x / 0.89 * nFriends_x * 0.94 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * 0.9039 * 0.9039 * per_gender_y + 0.7889 * per_privacy_y * 0.698 * per_privacy_y * per_privacy_y % 0.6383 / 0.6383 * 0.6943 * per_privacy_y + 0.1683 * 0.7386 ** 0.8809 / per_homeProvince_y // 0.6273 % 0.1972 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 903: Best fitness 0.8499896694214875, Best expression 0.0073 / per_privacy_y % nFriends_x / 0.89 * nFriends_x * 0.94 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * 0.9039 * 0.9039 * per_gender_y + 0.7889 * per_privacy_y * 0.698 * per_privacy_y * per_privacy_y % 0.6383 / 0.6383 * 0.6943 * per_privacy_y + 0.1683 * 0.7386 ** 0.8809 / per_homeProvince_y // 0.6273 % 0.1972 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 904: Best fitness 0.8499896694214875, Best expression 0.0073 / per_privacy_y % nFriends_x / 0.89 * nFriends_x * 0.94 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * 0.9039 * 0.9039 * per_gender_y + 0.7889 * per_privacy_y * 0.698 * per_privacy_y * per_privacy_y % 0.6383 / 0.6383 * 0.6943 * per_privacy_y + 0.1683 * 0.7386 ** 0.8809 / per_homeProvince_y // 0.6273 % 0.1972 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 905: Best fitness 0.8499896694214875, Best expression 0.0073 / per_privacy_y % nFriends_x / 0.89 * nFriends_x * 0.94 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * 0.9039 * 0.9039 * per_gender_y + 0.7889 * per_privacy_y * 0.698 * per_privacy_y * per_privacy_y % 0.6383 / 0.6383 * 0.6943 * per_privacy_y + 0.1683 * 0.7386 ** 0.8809 / per_homeProvince_y // 0.6273 % 0.1972 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 906: Best fitness 0.8499896694214875, Best expression 0.0073 / per_privacy_y % nFriends_x / 0.89 * nFriends_x * 0.94 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * 0.9039 * 0.9039 * per_gender_y + 0.7889 * per_privacy_y * 0.698 * per_privacy_y * per_privacy_y % 0.6383 / 0.6383 * 0.6943 * per_privacy_y + 0.1683 * 0.7386 ** 0.8809 / per_homeProvince_y // 0.6273 % 0.1972 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 907: Best fitness 0.8499896694214875, Best expression 0.0073 / per_privacy_y % nFriends_x / 0.89 * nFriends_x * 0.94 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * 0.9039 * 0.9039 * per_gender_y + 0.7889 * per_privacy_y * 0.698 * per_privacy_y * per_privacy_y % 0.6383 / 0.6383 * 0.6943 * per_privacy_y + 0.1683 * 0.7386 ** 0.8809 / per_homeProvince_y // 0.6273 % 0.1972 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 908: Best fitness 0.8499896694214875, Best expression 0.0073 / per_privacy_y % nFriends_x / 0.89 * nFriends_x * 0.94 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * 0.9039 * 0.9039 * per_gender_y + 0.7889 * per_privacy_y * 0.698 * per_privacy_y * per_privacy_y % 0.6383 / 0.6383 * 0.6943 * per_privacy_y + 0.1683 * 0.7386 ** 0.8809 / per_homeProvince_y // 0.6273 % 0.1972 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 909: Best fitness 0.8499896694214875, Best expression 0.0073 / per_privacy_y % nFriends_x / 0.89 * nFriends_x * 0.94 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * 0.9039 * 0.9039 * per_gender_y + 0.7889 * per_privacy_y * 0.698 * per_privacy_y * per_privacy_y % 0.6383 / 0.6383 * 0.6943 * per_privacy_y + 0.1683 * 0.7386 ** 0.8809 / per_homeProvince_y // 0.6273 % 0.1972 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 910: Best fitness 0.8499896694214875, Best expression 0.0073 / per_privacy_y % nFriends_x / 0.89 * nFriends_x * 0.94 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * 0.9039 * 0.9039 * per_gender_y + 0.7889 * per_privacy_y * 0.698 * per_privacy_y * per_privacy_y % 0.6383 / 0.6383 * 0.6943 * per_privacy_y + 0.1683 * 0.7386 ** 0.8809 / per_homeProvince_y // 0.6273 % 0.1972 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 911: Best fitness 0.8499896694214875, Best expression 0.0073 / per_privacy_y % nFriends_x / 0.89 * nFriends_x * 0.94 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * 0.9039 * 0.9039 * per_gender_y + 0.7889 * per_privacy_y * 0.698 * per_privacy_y * per_privacy_y % 0.6383 / 0.6383 * 0.6943 * per_privacy_y + 0.1683 * 0.7386 ** 0.8809 / per_homeProvince_y // 0.6273 % 0.1972 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 912: Best fitness 0.8499896694214875, Best expression 0.0073 / per_privacy_y % nFriends_x / 0.89 * nFriends_x * 0.94 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * 0.9039 * 0.9039 * per_gender_y + 0.7889 * per_privacy_y * 0.698 * per_privacy_y * per_privacy_y % 0.6383 / 0.6383 * 0.6943 * per_privacy_y + 0.1683 * 0.7386 ** 0.8809 / per_homeProvince_y // 0.6273 % 0.1972 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 913: Best fitness 0.8499896694214875, Best expression 0.0073 / per_privacy_y % nFriends_x / 0.89 * nFriends_x * 0.94 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * 0.9039 * 0.9039 * per_gender_y + 0.7889 * per_privacy_y * 0.698 * per_privacy_y * per_privacy_y % 0.6383 / 0.6383 * 0.6943 * per_privacy_y + 0.1683 * 0.7386 ** 0.8809 / per_homeProvince_y // 0.6273 % 0.1972 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y
# Generation 914: Best fitness 0.8499896694214875, Best expression 0.0073 / per_privacy_y % nFriends_x / 0.89 * nFriends_x * 0.94 * per_privacy_y + cn + 0.537553 * 0.1938 * per_location_y + 0.119332 % per_homeCity_y + 0.636472 * 0.2755 * 0.7928 * 0.7928 * 0.9039 * 0.9039 * per_gender_y + 0.7889 * per_privacy_y * 0.698 * per_privacy_y * per_privacy_y % 0.6383 / 0.6383 * 0.6943 * per_privacy_y + 0.1683 * 0.7386 ** 0.8809 / per_homeProvince_y // 0.6273 % 0.1972 * per_gender_y + 0.087997 * 0.3365 * 0.3365 * 0.3365 % per_fName_y

# %% [markdown]
# 724
